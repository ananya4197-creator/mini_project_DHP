# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Ananya Kushwaha\OneDrive\Desktop\Mini_project\WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# ## 1. Calculate total revenue by contract type.

# %%
df.groupby("Contract")["TotalCharges"].sum()
# Out:
# Contract
# Month-to-month    29.85108.15151.65820.51949.4301.93046.05587.45...
# One year          1889.51840.753487.955681.11022.95202.251874.45...
# Two year          326.87895.157382.253505.16369.456766.957251.74...
# Name: TotalCharges, dtype: object

# %% [markdown]
# ## 2. Find average monthly charges by contract type.

# %%
df.groupby("Contract")["MonthlyCharges"].mean()
# Out:
# Contract
# Month-to-month    66.398490
# One year          65.048608
# Two year          60.770413
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# ## 3. Calculate churn rate.

# %%
churn_rate = (df["Churn"] == "Yes").mean() * 100
print("Churn Rate:", churn_rate)
# Out:
# Churn Rate: 26.536987079369588

# %% [markdown]
# ## 4. Identify customers with tenure greater than 24 months.

# %%
df[df["tenure"] > 24]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %% [markdown]
# ## 5. Find top 10 highest paying customers.(based on total charges)

# %%
df.sort_values(by="TotalCharges", ascending=False).head(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2845  9093-FPDLG  Female              0      No         No      11
# 3353  4536-PLEQY    Male              0     Yes         No      12
# 3686  5899-MQZZL  Female              0      No         No      13
# 5598  6051-PTVNS  Female              0     Yes        Yes      55
# 6646  8249-THVEC    Male              0     Yes        Yes      51
# 6179  6328-ZPBGN  Female              1      No         No      11
# 1935  7297-DVYGA  Female              0      No         No      51
# 348   6243-OZGFH  Female              0      No         No      23
# 2715  0484-JPBRU    Male              0      No         No      41
# 5842  2971-SGAFL  Female              0      No         No      13
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2845          Yes                No     Fiber optic                   No  ...
# ...

# %% [markdown]
# ## 6. Compare average monthly charges bill between churn and non-churn customers.

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# ## 7. Find contract type with highest churn.

# %%
df.groupby("Contract")["Churn"].count().idxmax()
# Out:
# 'Month-to-month'

# %% [markdown]
# ## 8. Identify customers with monthly charges greater than 80.

# %%
df[df["MonthlyCharges"] > 80]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7025  2823-LKABH  Female              0      No         No      18
# 7034  0639-TSIQW  Female              0      No         No      67
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5             Yes           Yes     Fiber optic             No  ...
# ...

# %% [markdown]
# ## 9. Calculate average tenure by contract type.

# %%
df.groupby("Contract")["tenure"].mean()
# Out:
# Contract
# Month-to-month    18.036645
# One year          42.044807
# Two year          56.735103
# Name: tenure, dtype: float64

# %% [markdown]
# ## 10. Find total customers per contract.

# %%
df["Contract"].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
